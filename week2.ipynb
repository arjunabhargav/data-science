# %%
import requests
from bs4 import BeautifulSoup as bs
import lxml
import csv
import pandas as pd

file = open("trial.csv","w",encoding="utf-8")
writer = csv.writer(file)
writer.writerow(["Title","Date","Description","Link"])
feed = open("urls_feed.txt","r")
urls = feed.read()
urls = urls.split("\n")

for url in urls:
    try:
            r = requests.get(url)
            status_code = r.status_code
    except Exception as e:
            print('Error fetching the URL: ', url)
            print(e)
    try:    
            soup = bs(r.text, 'lxml')
    except Exception as e:
            print('Could not parse the xml: ', url)
            print(e)
    items = soup.findAll('item')
    for item in items:
        try:
            items_dicts = {'Title':item.find('title').text,'Date':item.find('pubdate').text,'Description':item.find('description').text,'Link':item.link.next_sibling.replace('\n','').replace('\t','')}
        except:
            items_dict = {'Title':item.find('title').text}
        f = csv.DictWriter(file, items_dicts.keys())
        f.writerow(items_dicts)

# %%
data = pd.read_csv('trial.csv') 
data
# Out:
#                                                   Title  \
# 0     Data Science mit Python – Aktuelle Buchempfehl...
# 1     Business Intelligence – 5 Tips for better Repo...
# 2      6 Ways to Optimize Your Database for Performance
# 3                                           CAP Theorem
# 4     Graphical understanding of dynamic programming...
# ...                                                 ...
# 1130  Revving Up & Accelerating Into a Sustainable F...
# 1131  How Does One Acre Fund Use Dataiku to Increase...
# 1132  You Won’t Scale AI Without Enlisting Non-Exper...
# 1133  Bring New People and Roles Into AI Projects Wi...
# 1134  3 Career Options for Data Scientists Who Want ...
#
#                                  Date  \
# 0     Sat, 04 Dec 2021 09:56:08 +0000
# 1     Sat, 06 Nov 2021 16:04:05 +0000
# 2     Mon, 25 Oct 2021 08:57:01 +0000
# 3     Thu, 14 Oct 2021 08:51:11 +0000
# 4     Tue, 05 Oct 2021 09:50:14 +0000
# ...                               ...
# 1130    Fri, 03 Dec 2021 14:33:00 GMT
# 1131    Thu, 02 Dec 2021 12:15:00 GMT
# 1132    Wed, 01 Dec 2021 15:46:52 GMT
# 1133    Tue, 30 Nov 2021 17:15:00 GMT
# 1134    Mon, 29 Nov 2021 17:27:36 GMT
#
#                                             Description  \
# 0     Als Dozent für Data Science und Python Program...
# 1     Data and BI Analysts often concentrate on lear...
# 2     Knowing how to optimize your organization’s da...
# 3     Understanding databases for storing, updating ...
# 4     This is the second article of the series My el...
# ...                                                 ...
# 1130  <div class="hs-featured-image-wrapper"> \r\r\n...
# 1131  <div class="hs-featured-image-wrapper"> \r\r\n...
# 1132  <div class="hs-featured-image-wrapper"> \r\r\n...
# 1133  <div class="hs-featured-image-wrapper"> \r\r\n...
# 1134  <div class="hs-featured-image-wrapper"> \r\r\n...
#
#                                                    Link
# 0     https://data-science-blog.com/blog/2021/12/04/...
# 1     https://data-science-blog.com/blog/2021/11/06/...
# 2     https://data-science-blog.com/blog/2021/10/25/...
# 3     https://data-science-blog.com/blog/2021/10/14/...
# 4     https://data-science-blog.com/blog/2021/10/05/...
# ...                                                 ...
# 1130  https://blog.dataiku.com/a-sustainable-future-...
# 1131     https://blog.dataiku.com/one-acre-fund\r
# 1132  https://blog.dataiku.com/scaling-ai-with-non-e...
# 1133        https://blog.dataiku.com/dataiku-10\r
# 1134  https://blog.dataiku.com/data-scientist-job-mo...
#
# [1135 rows x 4 columns]
